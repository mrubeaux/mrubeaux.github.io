# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "MathieuRubeauxConferences.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "category": "conferences",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "MathieuRubeauxArticles.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "category": "manuscripts",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"] + '"\n'

            md += """category: """ +  publist[pubsource]["category"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED fourcade_combining_2020: " Combining {Superpixels} and {Deep} {Learning} {Approaches} t ... "
# SUCESSFULLY PARSED moreau_comparison_2020: " Comparison between traditional and deep learning-based semi- ... "
# SUCESSFULLY PARSED fourcade_active_2020: " Active {Organs} {Segmentation} in {Metastatic} {Breast} {Can ... "
# SUCESSFULLY PARSED rubeaux_motion_2017: " Motion correction for imaging small lesions in coronary posi ... "
# SUCESSFULLY PARSED betancur_automatic_2016: " Automatic valve plane localization in myocardial perfusion { ... "
# SUCESSFULLY PARSED rubeaux_dense_2009: " Dense motion estimation of the heart based on cumulants  "
# SUCESSFULLY PARSED rubeaux_cardiac_2016: " Cardiac motion compensation improves reproducibility of {18F ... "
# SUCESSFULLY PARSED rubeaux_motion-frozen_2015: " “{Motion}-frozen” {18F}-sodium fluoride {PET} for imaging co ... "
# SUCESSFULLY PARSED moreau_comparison_2021: " Comparison between threshold-based and deep learning-based b ... "
# SUCESSFULLY PARSED shusharina_using_2021: " Using {Elastix} to {Register} {Inhale}/{Exhale} {Intrasubjec ... "
# SUCESSFULLY PARSED santini_unpaired_2020: " Unpaired {PET}/{CT} image synthesis of liver region using {C ... "
# SUCESSFULLY PARSED rubeaux_approximation_2011: " Approximation {De} {L}'information {Mutuelle} {Basée} {Sur}  ... "
# SUCESSFULLY PARSED rubeaux_edgeworth-based_2010: " Edgeworth-based approximation of {Mutual} {Information} for  ... "
# SUCESSFULLY PARSED rubeaux_numerical_2012: " Numerical phantom generation to evaluate non-rigid {CT}/{CBC ... "
# SUCESSFULLY PARSED rubeaux_evaluation_2013: " Evaluation of non-rigid constrained {CT}/{CBCT} registration ... "
# SUCESSFULLY PARSED romero_thalamic_2015: " Thalamic volume as a biomarker for disorders of consciousnes ... "
# SUCESSFULLY PARSED styner_automatic_2016: " Automatic detection of cardiovascular risk in {CT} attenuati ... "
# SUCESSFULLY PARSED styner_demons_2016: " Demons versus level-set motion registration for coronary$^{\ ... "
# SUCESSFULLY PARSED moreau_deep_2020: " Deep learning approaches for bone and bone lesion segmentati ... "
# SUCESSFULLY PARSED santini_automatic_2021: " Automatic classification of benign and malignant kidney mass ... "
# SUCESSFULLY PARSED colombie_feasibility_2022: " Feasibility of creation of a clinico-biological database: {A ... "
# SUCESSFULLY PARSED moreau_influence_2022: " Influence of inputs for bone lesion segmentation in longitud ... "
# SUCESSFULLY PARSED fourcade_percist-like_2022: " {PERCIST}-like response assessment with {FDG} {PET} based on ... "
# SUCESSFULLY PARSED villa_predicting_2025: " Predicting recurrence in head and neck cancer using new thre ... "
# SUCESSFULLY PARSED santini_segmentation_2020: " Segmentation automatique des métastases hépatiques en imager ... "
# SUCESSFULLY PARSED santini_quantification_2021: " Quantification automatique de l’activité de fond pour le cal ... "
# SUCESSFULLY PARSED doris_optimization_2018: " Optimization of {Reconstruction} and {Quantification} for {M ... "
# SUCESSFULLY PARSED torres_inclusion_2026: " Inclusion of ipsilateral salivary gland {PET}/{CT} features  ... "
# SUCESSFULLY PARSED doris_motion-corrected_2017: " Motion-corrected imaging of the aortic valve with {18F}-{NaF ... "
# SUCESSFULLY PARSED krishnan_molecular_2017: " Molecular {Imaging} of {Vulnerable} {Coronary} {Plaque}: {A} ... "
# SUCESSFULLY PARSED rubeaux_enhancing_2017: " Enhancing {Cardiac} {PET} by {Motion} {Correction} {Techniqu ... "
# SUCESSFULLY PARSED hyun_technical_2017: " Technical consideration for dual {ECG}/respiratory-gated car ... "
# SUCESSFULLY PARSED betancur_automatic_2017: " Automatic {Valve} {Plane} {Localization} in {Myocardial} {Pe ... "
# SUCESSFULLY PARSED brodov_quantitation_2016: " Quantitation of left ventricular ejection fraction reserve f ... "
# SUCESSFULLY PARSED slomka_dual-gated_2015: " Dual-gated motion-frozen cardiac {PET} with flurpiridaz {F}  ... "
# SUCESSFULLY PARSED isgum_automatic_2017: " Automatic determination of cardiovascular risk by {CT} atten ... "
# SUCESSFULLY PARSED hell_epicardial_2016: " Epicardial adipose tissue volume but not density is an indep ... "
# SUCESSFULLY PARSED colombie_epicure_2021: " The {EPICURE} study: a pilot prospective cohort study of het ... "
# SUCESSFULLY PARSED hering_learn2reg_2023: " {Learn2Reg}: {Comprehensive} {Multi}-{Task} {Medical} {Image ... "
# SUCESSFULLY PARSED moreau_automatic_2021: " Automatic {Segmentation} of {Metastatic} {Breast} {Cancer} { ... "
# SUCESSFULLY PARSED fourcade_deformable_2022: " Deformable image registration with deep network priors: a st ... "
# SUCESSFULLY PARSED rubeaux_medical_2014: " Medical image registration using {Edgeworth}-based approxima ... "
# SUCESSFULLY PARSED rubeaux_motion_2016: " Motion {Correction} of$^{\textrm{18}}$ {F}-{NaF} {PET} for { ... "
# SUCESSFULLY PARSED doris_optimization_2020: " Optimization of reconstruction and quantification of motion- ... "
# SUCESSFULLY PARSED rubeaux_normal_2016: " Normal {Databases} for the {Relative} {Quantification} of {M ... "
# SUCESSFULLY PARSED slomka_quantification_2017: " Quantification with normal limits: {New} cameras and low-dos ... "
