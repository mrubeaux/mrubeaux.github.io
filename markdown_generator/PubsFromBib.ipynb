# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "MathieuRubeaux.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED fourcade_combining_2020: " Combining {Superpixels} and {Deep} {Learning} {Approaches} t ... "
# SUCESSFULLY PARSED moreau_comparison_2020: " Comparison between traditional and deep learning-based semi- ... "
# SUCESSFULLY PARSED fourcade_active_2020: " Active {Organs} {Segmentation} in {Metastatic} {Breast} {Can ... "
# SUCESSFULLY PARSED rubeaux_motion_2017: " Motion correction for imaging small lesions in coronary posi ... "
# WARNING Missing Expected Field 'booktitle' from entry doris_motion-corrected_2017: " Motion-corrected imaging of th ... "
# WARNING Missing Expected Field 'booktitle' from entry krishnan_molecular_2017: " Molecular {Imaging} of {Vulner ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_enhancing_2017: " Enhancing {Cardiac} {PET} by { ... "
# WARNING Missing Expected Field 'booktitle' from entry hyun_technical_2017: " Technical consideration for du ... "
# WARNING Missing Expected Field 'booktitle' from entry betancur_automatic_2017: " Automatic {Valve} {Plane} {Loc ... "
# WARNING Missing Expected Field 'booktitle' from entry brodov_quantitation_2016: " Quantitation of left ventricul ... "
# SUCESSFULLY PARSED betancur_automatic_2016: " Automatic valve plane localization in myocardial perfusion { ... "
# WARNING Missing Expected Field 'booktitle' from entry slomka_dual-gated_2015: " Dual-gated motion-frozen cardi ... "
# SUCESSFULLY PARSED rubeaux_dense_2009: " Dense motion estimation of the heart based on cumulants  "
# WARNING Missing Expected Field 'booktitle' from entry isgum_automatic_2017: " Automatic determination of car ... "
# SUCESSFULLY PARSED rubeaux_cardiac_2016: " Cardiac motion compensation improves reproducibility of {18F ... "
# WARNING Missing Expected Field 'booktitle' from entry hell_epicardial_2016: " Epicardial adipose tissue volu ... "
# SUCESSFULLY PARSED rubeaux_motion-frozen_2015: " “{Motion}-frozen” {18F}-sodium fluoride {PET} for imaging co ... "
# SUCESSFULLY PARSED moreau_comparison_2021: " Comparison between threshold-based and deep learning-based b ... "
# SUCESSFULLY PARSED shusharina_using_2021: " Using {Elastix} to {Register} {Inhale}/{Exhale} {Intrasubjec ... "
# SUCESSFULLY PARSED santini_unpaired_2020: " Unpaired {PET}/{CT} image synthesis of liver region using {C ... "
# SUCESSFULLY PARSED rubeaux_approximation_2011: " Approximation {De} {L}'information {Mutuelle} {Basée} {Sur}  ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_approximation_2011-1: " Approximation de l'{Informatio ... "
# WARNING Missing Expected Field 'booktitle' from entry colombie_epicure_2021: " The {EPICURE} study: a pilot p ... "
# WARNING Missing Expected Field 'booktitle' from entry hering_learn2reg_2023: " {Learn2Reg}: {Comprehensive} { ... "
# WARNING Missing Expected Field 'booktitle' from entry moreau_automatic_2021: " Automatic {Segmentation} of {M ... "
# WARNING Missing Expected Field 'booktitle' from entry fourcade_deformable_2022: " Deformable image registration  ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_medical_2014: " Medical image registration usi ... "
# SUCESSFULLY PARSED rubeaux_edgeworth-based_2010: " Edgeworth-based approximation of {Mutual} {Information} for  ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_numerical_2012: " Numerical phantom generation t ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_evaluation_2013: " Evaluation of non-rigid constr ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_motion_2016: " Motion {Correction} of$^{\text ... "
# WARNING Missing Expected Field 'booktitle' from entry romero_thalamic_2015: " Thalamic volume as a biomarker ... "
# WARNING Missing Expected Field 'booktitle' from entry styner_automatic_2016: " Automatic detection of cardiov ... "
# WARNING Missing Expected Field 'booktitle' from entry styner_demons_2016: " Demons versus level-set motion ... "
# WARNING Missing Expected Field 'booktitle' from entry doris_optimization_2020: " Optimization of reconstruction ... "
# WARNING Missing Expected Field 'booktitle' from entry santini_kidney_2019: " Kidney tumor segmentation usin ... "
# SUCESSFULLY PARSED moreau_deep_2020: " Deep learning approaches for bone and bone lesion segmentati ... "
# SUCESSFULLY PARSED santini_automatic_2021: " Automatic classification of benign and malignant kidney mass ... "
# SUCESSFULLY PARSED colombie_feasibility_2022: " Feasibility of creation of a clinico-biological database: {A ... "
# SUCESSFULLY PARSED moreau_influence_2022: " Influence of inputs for bone lesion segmentation in longitud ... "
# SUCESSFULLY PARSED fourcade_percist-like_2022: " {PERCIST}-like response assessment with {FDG} {PET} based on ... "
# SUCESSFULLY PARSED villa_predicting_2025: " Predicting recurrence in head and neck cancer using new thre ... "
# SUCESSFULLY PARSED santini_segmentation_2020: " Segmentation automatique des métastases hépatiques en imager ... "
# SUCESSFULLY PARSED santini_quantification_2021: " Quantification automatique de l’activité de fond pour le cal ... "
# WARNING Missing Expected Field 'booktitle' from entry rubeaux_normal_2016: " Normal {Databases} for the {Re ... "
# WARNING Missing Expected Field 'booktitle' from entry slomka_quantification_2017: " Quantification with normal lim ... "
# WARNING Missing Expected Field 'booktitle' from entry doris_optimization_2018: " Optimization of {Reconstructio ... "
# WARNING Missing Expected Field 'booktitle' from entry torres_inclusion_2026: " Inclusion of ipsilateral saliv ... "
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\marubeaux\Mathieu\Perso\00_Website\venv\Lib\site-packages\pybtex\io.py:83, in _open(opener, filename_or_file, mode, **kwargs)
#      82     else:
# ---> 83         return _open_existing(opener, filename, mode, locate=kpsewhich, **kwargs)
#      84 except EnvironmentError as error:
#
# File c:\Users\marubeaux\Mathieu\Perso\00_Website\venv\Lib\site-packages\pybtex\io.py:57, in _open_existing(opener, filename, mode, locate, **kwargs)
#      56         filename = found
# ---> 57 return opener(filename, mode, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pubs.bib'
#
# During handling of the above exception, another exception occurred:
#
# PybtexError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 for pubsource in publist:
#       2     parser = bibtex.Parser()
# ----> 3     bibdata = parser.parse_file(publist[pubsource]["file"])
#       5     #loop through the individual references in a given bibtex file
#       6     for bib_id in bibdata.entries:
#       7         #reset default date
#
# File c:\Users\marubeaux\Mathieu\Perso\00_Website\venv\Lib\site-packages\pybtex\database\input\__init__.py:51, in BaseParser.parse_file(self, filename, file_suffix)
#      49 self.filename = filename
#      50 open_file = pybtex.io.open_unicode if self.unicode_io else pybtex.io.open_raw
# ---> 51 with open_file(filename, encoding=self.encoding) as f:
#      52     try:
#      53         self.parse_stream(f)
#
# File c:\Users\marubeaux\Mathieu\Perso\00_Website\venv\Lib\site-packages\pybtex\io.py:95, in open_unicode(filename, mode, encoding)
#      93 if encoding is None:
#      94     encoding = get_default_encoding()
# ---> 95 return _open(io.open, filename, mode, encoding=encoding)
#
# File c:\Users\marubeaux\Mathieu\Perso\00_Website\venv\Lib\site-packages\pybtex\io.py:85, in _open(opener, filename_or_file, mode, **kwargs)
#      83         return _open_existing(opener, filename, mode, locate=kpsewhich, **kwargs)
#      84 except EnvironmentError as error:
# ---> 85     raise PybtexError("unable to open %s. %s" % (filename, error.strerror))
#
# PybtexError: unable to open pubs.bib. No such file or directory
